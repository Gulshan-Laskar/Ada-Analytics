# %%
import pandas as pd

df = pd.read_csv(r'capitol_trades_data.csv')

# %%
df.describe()
# Out:
#                       Politician                     Issuer   Published  \
# count                       5988                       5988        5988
# unique                        99                       1356          85
# top     Ro KhannaDemocratHouseCA  NVIDIA CorporationNVDA:US  15 May2025
# freq                        1806                         85        1248
#
#            Traded Filed After   Owner  Type    Size    Price  \
# count        5988        5988    5988  5988    5988     5050
# unique        204         156       5     4       9     4081
# top     4 Apr2025      days38  Spouse  sell  1K–15K  $285.06
# freq          278         350    2575  3061    4164       11
#
#                                                Detail URL
# count                                                5988
# unique                                                 99
# top     https://www.capitoltrades.com/politicians/K000389
# freq                                                 1806

# %%
df.isnull().sum()
# Out:
# Politician       0
# Issuer           0
# Published        0
# Traded           0
# Filed After      0
# Owner            0
# Type             0
# Size             0
# Price          938
# Detail URL       0
# dtype: int64

# %%
df
# Out:
#                              Politician  \
# 0          Julie JohnsonDemocratHouseTX
# 1          Julie JohnsonDemocratHouseTX
# 2          Julie JohnsonDemocratHouseTX
# 3          Julie JohnsonDemocratHouseTX
# 4          Julie JohnsonDemocratHouseTX
# ...                                 ...
# 5983  Jefferson ShreveRepublicanHouseIN
# 5984  Jefferson ShreveRepublicanHouseIN
# 5985  Jefferson ShreveRepublicanHouseIN
# 5986  Jefferson ShreveRepublicanHouseIN
# 5987  Jefferson ShreveRepublicanHouseIN
#
#                                       Issuer       Published      Traded  \
# 0                        Blackrock IncBLK:US  13:05Yesterday  22 Jul2025
# 1                         Chevron CorpCVX:US  13:05Yesterday  25 Jul2025
# 2                         Chevron CorpCVX:US  13:05Yesterday  21 Jul2025
# 3                        CME Group IncCME:US  13:05Yesterday  22 Jul2025
# 4                     Exxon Mobil CorpXOM:US  13:05Yesterday  25 Jul2025
# ...
