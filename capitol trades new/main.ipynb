# %%
import pandas as pd

df = pd.read_csv(r'capitol_trades_data.csv')

# %%
df.describe()
# Out:
#                       Politician                     Issuer   Published  \
# count                      11978                      11977       11977
# unique                       101                       1357          86
# top     Ro KhannaDemocratHouseCA  NVIDIA CorporationNVDA:US  15 May2025
# freq                        3612                        170        2496
#
#            Traded Filed After   Owner   Type    Size    Price  \
# count       11977       11977   11977  11977   11977    10101
# unique        205         157       6      5      10     4082
# top     4 Apr2025      days38  Spouse   sell  1K–15K  $285.06
# freq          556         700    5150   6122    8328       22
#
#                                                Detail URL
# count                                               11977
# unique                                                100
# top     https://www.capitoltrades.com/politicians/K000389
# freq                                                 3612

# %%
df.isnull().sum()
# Out:
# Politician        0
# Issuer            1
# Published         1
# Traded            1
# Filed After       1
# Owner             1
# Type              1
# Size              1
# Price          1877
# Detail URL        1
# dtype: int64

# %%
df
# Out:
#                               Politician  \
# 0           Julie JohnsonDemocratHouseTX
# 1           Julie JohnsonDemocratHouseTX
# 2           Julie JohnsonDemocratHouseTX
# 3           Julie JohnsonDemocratHouseTX
# 4           Julie JohnsonDemocratHouseTX
# ...                                  ...
# 11973  Jefferson ShreveRepublicanHouseIN
# 11974  Jefferson ShreveRepublicanHouseIN
# 11975  Jefferson ShreveRepublicanHouseIN
# 11976  Jefferson ShreveRepublicanHouseIN
# 11977  Jefferson ShreveRepublicanHouseIN
#
#                                        Issuer       Published      Traded  \
# 0                         Blackrock IncBLK:US  13:05Yesterday  22 Jul2025
# 1                          Chevron CorpCVX:US  13:05Yesterday  25 Jul2025
# 2                          Chevron CorpCVX:US  13:05Yesterday  21 Jul2025
# 3                         CME Group IncCME:US  13:05Yesterday  22 Jul2025
# 4                      Exxon Mobil CorpXOM:US  13:05Yesterday  25 Jul2025
# ...

# %%
df_clean = pd.read_csv(r"capitol_trades_clean.csv")

# %%
df_clean
# Out:
#        politician_name politician_party politician_chamber politician_state  \
# 0        Julie Johnson         Democrat              House               TX
# 1        Julie Johnson         Democrat              House               TX
# 2        Julie Johnson         Democrat              House               TX
# 3        Julie Johnson         Democrat              House               TX
# 4        Julie Johnson         Democrat              House               TX
# ...                ...              ...                ...              ...
# 4749  Jefferson Shreve       Republican              House               IN
# 4750  Jefferson Shreve       Republican              House               IN
# 4751  Jefferson Shreve       Republican              House               IN
# 4752  Jefferson Shreve       Republican              House               IN
# 4753  Jefferson Shreve       Republican              House               IN
#
# ...

# %%
df_clean.dtypes
# Out:
# politician_name        object
# politician_party       object
# politician_chamber     object
# politician_state       object
# company                object
# ticker                 object
# type                   object
# owner                  object
# traded_dt              object
# published_dt           object
# published_note         object
# filed_after_days      float64
# size                   object
# size_low_usd          float64
# size_high_usd         float64
# price                  object
# price_usd             float64
# notional_low          float64
# notional_high         float64
# detail_url             object
# politician             object
# issuer                 object
# published              object
# traded                 object
# filed_after            object
# dtype: object
